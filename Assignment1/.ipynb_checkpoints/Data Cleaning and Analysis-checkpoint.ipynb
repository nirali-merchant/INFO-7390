# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series, DataFrame
plt.rcParams['figure.figsize'] = (30, 20)
import seaborn as sns

# %%
ccdf  = pd.read_csv('CryptocoinsHistoricalPrices.csv', sep = ',')

# %%
ccdf.head()
# Out:
#    Unnamed: 0        Date     Open     High      Low    Close          Volume  \
# 0           1  2018-01-09  15123.7  15497.5  14424.0  14595.4  16,660,000,000
# 1           2  2018-01-08  16476.2  16537.9  14208.2  15170.1  18,413,900,000
# 2           3  2018-01-07  17527.3  17579.6  16087.7  16477.6  15,866,000,000
# 3           4  2018-01-06  17462.1  17712.4  16764.6  17527.0  18,314,600,000
# 4           5  2018-01-05  15477.2  17705.2  15202.8  17429.5  23,840,900,000
#
#         Market.Cap coin     Delta
# 0  253,935,000,000  BTC -0.034932
# 1  276,612,000,000  BTC -0.079272
# 2  294,222,000,000  BTC -0.059889
# 3  293,091,000,000  BTC  0.003717
# 4  259,748,000,000  BTC  0.126140

# %%
ccdf.describe()
# Out:
#           Unnamed: 0          Open          High           Low         Close  \
# count  659360.000000  6.589970e+05  6.589740e+05  6.590250e+05  6.589970e+05
# mean   329680.500000  3.559294e+01  3.690036e+01  3.559681e+01  3.573178e+01
# std    190340.981084  1.049211e+03  1.065091e+03  1.092414e+03  1.050554e+03
# min         1.000000  1.000000e-10  1.300000e-10  9.200000e-14  1.000000e-10
# 25%    164840.750000  4.120000e-04  4.820000e-04  3.550000e-04  4.130000e-04
# 50%    329680.500000  6.664000e-03  7.708500e-03  5.815000e-03  6.684000e-03
# 75%    494520.250000  9.626900e-02  1.112207e-01  8.400800e-02  9.675400e-02
# max    659360.000000  9.991780e+04  9.947900e+04  9.937920e+04  9.990380e+04
#
#                Delta
# count  658981.000000
# mean        0.182693
# std        57.551610
# min        -0.999963
# 25%        -0.065126
# 50%         0.000000
# 75%         0.066667
# max     34513.333333

# %%
ccdf.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Unnamed: 0      0
# Date            1
# Open          363
# High          386
# Low           335
# Close         363
# Volume          0
# Market.Cap      0
# coin            0
# Delta         379
# dtype: int64

# %%
ccdf.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            1
# Open          363
# High          386
# Low           335
# Close         363
# Volume          0
# Market.Cap      0
# coin            0
# Delta         379
# dtype: int64

# %%
ccdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 659360 entries, 0 to 659359
# Data columns (total 10 columns):
# Unnamed: 0    659360 non-null int64
# Date          659359 non-null object
# Open          658997 non-null float64
# High          658974 non-null float64
# Low           659025 non-null float64
# Close         658997 non-null float64
# Volume        659360 non-null object
# Market.Cap    659360 non-null object
# coin          659360 non-null object
# Delta         658981 non-null float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 50.3+ MB

# %% [markdown]
# # Identigy Missing Data

# %%
#drop rows where atleast 7 columns are present

ccdf.dropna(thresh=7)
# Out:
#         Unnamed: 0        Date          Open          High           Low  \
# 0                1  2018-01-09  15123.700000  15497.500000  14424.000000
# 1                2  2018-01-08  16476.200000  16537.900000  14208.200000
# 2                3  2018-01-07  17527.300000  17579.600000  16087.700000
# 3                4  2018-01-06  17462.100000  17712.400000  16764.600000
# 4                5  2018-01-05  15477.200000  17705.200000  15202.800000
# 5                6  2018-01-04  15270.700000  15739.700000  14522.200000
# 6                7  2018-01-03  14978.200000  15572.800000  14844.500000
# 7                8  2018-01-02  13625.000000  15444.600000  13163.600000
# 8                9  2018-01-01  14112.200000  14112.200000  13154.700000
# 9               10  2017-12-31  12897.700000  14377.400000  12755.600000
# 10              11  2017-12-30  14681.900000  14681.900000  12350.100000
# 11              12  2017-12-29  14695.800000  15279.000000  14307.000000
# ...

# %%
# Identify which index is null for Date column
ccdf.loc[ccdf['Date'].isnull() == True]
# Out:
#         Unnamed: 0 Date  Open  High  Low  Close  \
# 659349      659350  NaN   NaN   NaN  NaN    NaN
#
#                                                  Volume  \
# 659349  No data was found for the selected time period.
#
#                                              Market.Cap  coin  Delta
# 659349  No data was found for the selected time period.  FRCT    NaN

# %%
# Retrieve the index for null value in Date and drop it
ccdf = ccdf.drop(ccdf.loc[ccdf['Date'].isnull() == True].index)

# %%
# Check whether the row is dropped
ccdf.loc[ccdf['Date'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Date, Open, High, Low, Close, Volume, Market.Cap, coin, Delta]
# Index: []

# %%
ccdf['High'].fillna(ccdf['High'].mean(), inplace =True)

# %%
ccdf['Open'].fillna(ccdf['Open'].mean(), inplace =True)

# %%
ccdf.loc[ccdf['Open'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Date, Open, High, Low, Close, Volume, Market.Cap, coin, Delta]
# Index: []

# %%
ccdf.loc[ccdf['High'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Date, Open, High, Low, Close, Volume, Market.Cap, coin, Delta]
# Index: []

# %%
ccdf['Low'].fillna(ccdf['Low'].mean(), inplace =True)

# %%
ccdf.loc[ccdf['Low'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Date, Open, High, Low, Close, Volume, Market.Cap, coin, Delta]
# Index: []

# %%
ccdf['Close'].fillna(ccdf['Close'].mean(), inplace =True)

# %%
ccdf.loc[ccdf['Close'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Date, Open, High, Low, Close, Volume, Market.Cap, coin, Delta]
# Index: []

# %%
ccdf['Delta'].fillna(ccdf['Delta'].mean(), inplace =True)

# %%
ccdf.loc[ccdf['Delta'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Date, Open, High, Low, Close, Volume, Market.Cap, coin, Delta]
# Index: []

# %%
ccdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 659359 entries, 0 to 659359
# Data columns (total 10 columns):
# Unnamed: 0    659359 non-null int64
# Date          659359 non-null object
# Open          659359 non-null float64
# High          659359 non-null float64
# Low           659359 non-null float64
# Close         659359 non-null float64
# Volume        659359 non-null object
# Market.Cap    659359 non-null object
# coin          659359 non-null object
# Delta         659359 non-null float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 55.3+ MB

# %%
# Indenticcdf.loc[ccdf['Delta'] == 0]fy placeholder data
ccdf.loc[ccdf['Delta'] == 0]
# Out:
#         Unnamed: 0        Date        Open        High         Low  \
# 783            784  2015-11-18  334.590000  336.530000  330.640000
# 1616          1617  2013-08-07  106.750000  106.750000  106.750000
# 1697          1698  2013-05-18  123.500000  125.250000  122.300000
# 2107          2108  2016-12-16    7.860000    7.930000    7.800000
# 2150          2151  2016-11-03   10.800000   11.110000   10.760000
# 2199          2200  2016-09-15   11.940000   12.140000   11.920000
# 2226          2227  2016-08-19   10.750000   10.800000   10.730000
# 2421          2422  2016-02-06    2.530000    2.560000    2.470000
# 2442          2443  2016-01-16    1.220000    1.310000    1.170000
# 2579          2580  2015-09-01    1.350000    1.390000    1.340000
# 2622          2623  2017-12-23    1.170000    1.210000    1.080000
# 3064          3065  2016-10-07    0.007377    0.007459    0.007350
# 3237          3238  2016-04-17    0.006499    0.006605    0.006488
# ...

# %%
len(ccdf.loc[ccdf['Volume'] == '-'])
# Out:
# 6096

# %%
len(ccdf.loc[ccdf['Market.Cap'] == '-'])
# Out:
# 90092

# %%
ccdf = ccdf.drop(ccdf.loc[ccdf['Volume'] == '-'].index)

# %%
ccdf = ccdf.drop(ccdf.loc[ccdf['Market.Cap'] == '-'].index)

# %%
# Count after remving correcting bad or missing data
ccdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 563171 entries, 0 to 658456
# Data columns (total 10 columns):
# Unnamed: 0    563171 non-null int64
# Date          563171 non-null object
# Open          563171 non-null float64
# High          563171 non-null float64
# Low           563171 non-null float64
# Close         563171 non-null float64
# Volume        563171 non-null object
# Market.Cap    563171 non-null object
# coin          563171 non-null object
# Delta         563171 non-null float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 47.3+ MB

# %%
ccdf.head()
# Out:
#    Unnamed: 0        Date     Open     High      Low    Close          Volume  \
# 0           1  2018-01-09  15123.7  15497.5  14424.0  14595.4  16,660,000,000
# 1           2  2018-01-08  16476.2  16537.9  14208.2  15170.1  18,413,900,000
# 2           3  2018-01-07  17527.3  17579.6  16087.7  16477.6  15,866,000,000
# 3           4  2018-01-06  17462.1  17712.4  16764.6  17527.0  18,314,600,000
# 4           5  2018-01-05  15477.2  17705.2  15202.8  17429.5  23,840,900,000
#
#         Market.Cap coin     Delta
# 0  253,935,000,000  BTC -0.034932
# 1  276,612,000,000  BTC -0.079272
# 2  294,222,000,000  BTC -0.059889
# 3  293,091,000,000  BTC  0.003717
# 4  259,748,000,000  BTC  0.126140

# %%
sns.distplot(ccdf['Close'])

# %%
sns.boxplot(x= "Open", y ="coin" , data = ccdf)

# %%
(ccdf['Close']).hist()

# %%
sns.stripplot(x="coin", y="Open", data=ccdf);
